# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\omgai\Downloads\spam (1).csv")
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.Category.value_counts()
# Out:
# Category
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
df['spam']=df['Category'].apply(lambda x:1 if x=='spam' else 0)

# %%
df.head()
# Out:
#   Category                                            Message  spam
# 0      ham  Go until jurong point, crazy.. Available only ...     0
# 1      ham                      Ok lar... Joking wif u oni...     0
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3      ham  U dun say so early hor... U c already then say...     0
# 4      ham  Nah I don't think he goes to usf, he lives aro...     0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.Message, df.spam, test_size=0.2)

# %%
X_train.shape
# Out:
# (4457,)

# %%
X_test.shape
# Out:
# (1115,)

# %%
type(X_train)
# Out:
# pandas.core.series.Series

# %%
X_train[:4]
# Out:
# 3747               I'm not. She lip synced with shangela.
# 5459    If you hear a loud scream in about &lt;#&gt; m...
# 4894                               Send me the new number
# 1327                      Sorry, was in the bathroom, sup
# Name: Message, dtype: object

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
y_train[:4]
# Out:
# 3747    0
# 5459    0
# 4894    0
# 1327    0
# Name: spam, dtype: int64

# %%
type(X_train.values)
# Out:
# numpy.ndarray

# %%
from sklearn.feature_extraction.text import CountVectorizer

v = CountVectorizer()

X_train_cv = v.fit_transform(X_train.values)
X_train_cv
# Out:
# <4457x7750 sparse matrix of type '<class 'numpy.int64'>'
# 	with 59384 stored elements in Compressed Sparse Row format>

# %%
X_train_cv.toarray()[:2][0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
X_train_cv.shape
# Out:
# (4457, 7750)

# %%
v.get_feature_names_out()[1771]
# Out:
# 'charges'

# %%
v.vocabulary_
# Out:
# {'not': 4853,
#  'she': 6112,
#  'lip': 4177,
#  'synced': 6698,
#  'with': 7558,
#  'shangela': 6102,
#  'if': 3651,
#  'you': 7711,
#  'hear': 3430,
#  'loud': 4256,
#  'scream': 5991,
#  'in': 3688,
#  'about': 772,
#  'lt': 4282,
#  'gt': 3308,
#  'minutes': 4527,
#  'its': 3812,
#  'cause': 1722,
#  'my': 4687,
#  'gyno': 3337,
#  'will': 7528,
#  'be': 1299,
#  'shoving': 6166,
#  'things': 6868,
#  'up': 7197,
#  'me': 4435,
#  'that': 6832,
#  'don': 2443,
#  'belong': 1343,
#  'send': 6045,
#  'the': 6836,
#  'new': 4782,
#  'number': 4882,
#  'sorry': 6369,
#  'was': 7398,
#  'bathroom': 1277,
#  'sup': 6640,
#  'sir': 6223,
#  'need': 4749,
#  'axis': 1201,
#  'bank': 1247,
#  'account': 800,
#  'no': 4821,
#  'and': 984,
#  'address': 832,
#  'ey': 2773,
#  'calm': 1658,
#  'downon': 2467,
#  'theacusations': 6838,
#  'itxt': 3815,
#  'cos': 2055,
#  'iwana': 3819,
#  'know': 4002,
#  'wotu': 7618,
#  'doin': 2434,
#  'at': 1144,
#  'thew': 6861,
#  'end': 2623,
#  'haventcn': 3413,
#  'ages': 885,
#  'ring': 5820,
#  'ur': 7214,
#  'up4': 7198,
#  'nething': 4771,
#  'sat': 5945,
#  'love': 4261,
#  'xxx': 7661,
#  'please': 5279,
#  'attend': 1156,
#  'phone': 5215,
#  'tomorrow': 6979,
#  'am': 957,
#  'going': 3221,
#  'to': 6958,
#  'theatre': 6840,
#  'so': 6325,
#  'can': 1666,
#  'come': 1938,
#  'wherever': 7496,
#  'call': 1641,
#  'tell': 6777,
#  'where': 7494,
#  'when': 7490,
#  'yeah': 7685,
#  'what': 7483,
#  'thinking': 6872,
#  'aathi': 759,
#  'lot': 4249,
#  'kallis': 3937,
#  'is': 3795,
#  'ready': 5631,
#  'for': 2982,
#  'bat': 1271,
#  '2nd': 405,
#  'innings': 3734,
#  'hey': 3474,
#  'werethe': 7473,
#  'monkeespeople': 4592,
#  'say': 5960,
#  'we': 7425,
#  'monkeyaround': 4594,
#  'howdy': 3571,
#  'gorgeous': 3247,
#  'howu': 3574,
#  'foundurself': 3010,
#  'jobyet': 3882,
#  'sausage': 5954,
#  'jen': 3860,
#  'mode': 4577,
#  'men': 4470,
#  'or': 5001,
#  'have': 3409,
#  'left': 4111,
#  'jos': 3900,
#  'ask': 1121,
#  'wana': 7384,
#  'meet': 4452,
#  'yep': 7694,
#  'get': 3168,
#  'program': 5477,
#  're': 5620,
#  'slacking': 6256,
#  'future': 3100,
#  'planned': 5265,
#  'it': 3806,
#  'result': 5785,
#  'of': 4916,
#  'do': 2411,
#  'today': 6964,
#  'best': 1354,
#  'present': 5419,
#  'enjoy': 2638,
#  'sent': 6054,
#  'bucks': 1576,
#  'company': 1954,
#  'very': 7287,
#  'good': 3233,
#  'environment': 2662,
#  'terrific': 6801,
#  'food': 2973,
#  'really': 5639,
#  'nice': 4795,
#  'crashed': 2096,
#  'out': 5037,
#  'cuddled': 2141,
#  'on': 4960,
#  'sofa': 6328,
#  'esplanade': 2681,
#  'mind': 4511,
#  'giving': 3196,
#  'lift': 4150,
#  'got': 3251,
#  'car': 1686,
#  'wan2': 7383,
#  'win': 7531,
#  'greet': 3290,
#  'westlife': 7478,
#  'm8': 4316,
#  'they': 6862,
#  'are': 1076,
#  'currently': 2153,
#  'tour': 7020,
#  'unbreakable': 7149,
#  'untamed': 7195,
#  'unkempt': 7180,
#  'text': 6811,
#  '83049': 674,
#  'cost': 2057,
#  '50p': 549,
#  'std': 6498,
#  'how': 3568,
#  'masters': 4404,
#  'private': 5452,
#  'your': 7715,
#  '2003': 348,
#  'statement': 6489,
#  'shows': 6174,
#  '800': 649,
#  'un': 7146,
#  'redeemed': 5677,
#  'points': 5319,
#  '08715203685': 119,
#  'identifier': 3646,
#  'code': 1914,
#  '4xx26': 540,
#  'expires': 2759,
#  '13': 291,
#  '10': 253,
#  '04': 14,
#  'still': 6517,
#  'around': 1097,
#  'could': 2067,
#  'use': 7232,
#  'half': 3352,
#  '8th': 733,
#  'im': 3665,
#  'fine': 2898,
#  'babes': 1211,
#  'aint': 902,
#  'been': 1318,
#  'much': 4657,
#  'tho': 6885,
#  'saw': 5959,
#  'scary': 5970,
#  'movie': 4630,
#  'yest': 7697,
#  'quite': 5567,
#  'funny': 3095,
#  'want': 7386,
#  '2mrw': 404,
#  'afternoon': 871,
#  'town': 7022,
#  'mall': 4365,
#  'sumthin': 6630,
#  'xx': 7659,
#  'customer': 2160,
#  'service': 6066,
#  'announcement': 1001,
#  'recently': 5660,
#  'tried': 7057,
#  'make': 4358,
#  'delivery': 2275,
#  'but': 1610,
#  'were': 7471,
#  'unable': 7147,
#  '07090298926': 23,
#  'schedule': 5974,
#  'ref': 5679,
#  '9307622': 741,
#  'divorce': 2403,
#  'lol': 4221,
#  'here': 3467,
#  'aight': 900,
#  'thanks': 6828,
#  'again': 876,
#  'comin': 1942,
#  'loan': 4204,
#  'any': 1020,
#  'purpose': 5537,
#  '500': 543,
#  '75': 627,
#  '000': 1,
#  'homeowners': 3526,
#  'tenants': 6789,
#  'welcome': 7462,
#  'previously': 5435,
#  'refused': 5688,
#  'help': 3454,
#  'free': 3029,
#  '0800': 43,
#  '1956669': 324,
#  'back': 1219,
#  'maybe': 4429,
#  'should': 6160,
#  'find': 2895,
#  'something': 6343,
#  'else': 2604,
#  'instead': 3751,
#  'short': 6153,
#  'cute': 2165,
#  'person': 5190,
#  'dont': 2447,
#  'try': 7076,
#  'prove': 5503,
#  'gud': 3313,
#  'mrng': 4637,
#  'cant': 1677,
#  'pick': 5229,
#  'right': 5814,
#  'now': 4866,
#  'pls': 5287,
#  'message': 4482,
#  'wen': 7467,
#  'lovable': 4260,
#  'bcums': 1296,
#  'angry': 991,
#  'wid': 7516,
#  'dnt': 2410,
#  'take': 6717,
#  'seriously': 6063,
#  'coz': 2083,
#  'being': 1336,
#  'most': 4615,
#  'childish': 1819,
#  'true': 7069,
#  'way': 7420,
#  'showing': 6171,
#  'deep': 2249,
#  'affection': 861,
#  'care': 1690,
#  'luv': 4298,
#  'kettoda': 3962,
#  'manda': 4371,
#  'day': 2214,
#  'da': 2174,
#  'urgent': 7218,
#  'mobile': 4568,
#  'awarded': 1193,
#  'bonus': 1452,
#  'caller': 1649,
#  'prize': 5455,
#  '02': 8,
#  '09': 155,
#  '03': 13,
#  'this': 6878,
#  'our': 5034,
#  'attempt': 1155,
#  'contact': 2013,
#  '0871': 90,
#  '872': 707,
#  '9755': 745,
#  'box95qu': 1497,
#  'ma': 4319,
#  'fan': 2807,
#  'single': 6217,
#  'line': 4166,
#  'big': 1374,
#  'meaning': 4439,
#  'miss': 4535,
#  'anything': 1028,
#  'life': 4145,
#  'nyt': 4897,
#  'congratulations': 1998,
#  'cd': 1730,
#  'vouchers': 7341,
#  '125gift': 287,
#  'guaranteed': 3312,
#  'entry': 2657,
#  '100': 254,
#  'wkly': 7570,
#  'draw': 2478,
#  'txt': 7109,
#  'music': 4678,
#  '87066': 701,
#  'tncs': 6957,
#  'www': 7646,
#  'ldew': 4092,
#  'com1win150ppmx3age16': 1933,
#  'di': 2327,
#  'yet': 7699,
#  'just': 3921,
#  'like': 4155,
#  'keep': 3953,
#  'touch': 7016,
#  'easiest': 2546,
#  'from': 3066,
#  'barcelona': 1252,
#  'by': 1625,
#  'ru': 5875,
#  'house': 3563,
#  'charles': 1773,
#  'late': 4071,
#  'reply': 5746,
#  'an': 980,
#  'hour': 3561,
#  'apeshit': 1038,
#  'sometimes': 6345,
#  'heart': 3434,
#  'remembrs': 5719,
#  'someone': 6339,
#  'forgets': 2990,
#  'soon': 6359,
#  'bcoz': 1294,
#  'everyone': 2708,
#  'liked': 4156,
#  'ones': 4966,
#  'remembered': 5716,
#  'everytime': 2712,
#  'bslvyl': 1568,
#  'well': 7464,
#  'done': 2445,
#  'ya': 7671,
#  'all': 934,
#  'll': 4197,
#  'appointment': 1056,
#  'happy': 3386,
#  'years': 7687,
#  'melody': 4464,
#  'yesterday': 7698,
#  'wonderful': 7589,
#  'hope': 3540,
#  'enjoyed': 2639,
#  'burial': 1597,
#  'mojibiola': 4582,
#  'piggy': 5241,
#  'awake': 1191,
#  'bet': 1356,
#  'sleeping': 6261,
#  'lunch': 4293,
#  'theyre': 6863,
#  'doing': 2436,
#  'lots': 4251,
#  'places': 5259,
#  'only': 4971,
#  'hospitals': 3553,
#  'medical': 4448,
#  'safe': 5907,
#  'reserve': 5762,
#  'ticket': 6915,
#  'saturday': 5952,
#  'eve': 2696,
#  'chennai': 1804,
#  'thirunelvali': 6877,
#  'tirunelvali': 6938,
#  'sunday': 6633,
#  'already': 945,
#  'see': 6019,
#  'net': 4769,
#  'available': 1180,
#  'book': 1455,
#  'through': 6900,
#  'tackle': 6707,
#  'later': 4074,
#  'reach': 5621,
#  'before': 1324,
#  'ten': 6788,
#  'morning': 4611,
#  'hun': 3599,
#  'onbus': 4962,
#  'goin': 3219,
#  'him': 3488,
#  'he': 3419,
#  'wants': 7390,
#  '2go': 391,
#  '4a': 517,
#  'meal': 4436,
#  'donyt': 2449,
#  'feel': 2842,
#  'cuz': 2169,
#  'last': 4069,
#  'bus': 1603,
#  'home': 3525,
#  'hes': 3471,
#  'sweet': 6682,
#  'latelyxxx': 4073,
#  'final': 2890,
#  'chance': 1757,
#  'claim': 1859,
#  '150': 302,
#  'worth': 7615,
#  'discount': 2387,
#  'yes': 7696,
#  '85023': 691,
#  'savamob': 5955,
#  'member': 4465,
#  'offers': 4926,
#  'cs': 2130,
#  'pobox84': 5309,
#  'm263uz': 4313,
#  '00': 0,
#  'subs': 6589,
#  '16': 314,
#  'file': 2879,
#  'bag': 1225,
#  'work': 7601,
#  'called': 1648,
#  'room': 5853,
#  'career': 1692,
#  'tel': 6773,
#  'added': 828,
#  'as': 1111,
#  'indyarocks': 3717,
#  'com': 1932,
#  'sms': 6304,
#  'remove': 5727,
#  'phonebook': 5217,
#  'desparate': 2301,
#  'recorded': 5668,
#  'other': 5026,
#  'listen': 4181,
#  'sound': 6378,
#  'voice': 7332,
#  'hm': 3503,
#  'headache': 3421,
#  'anyone': 1024,
#  'saying': 5963,
#  'order': 5009,
#  'slippers': 6272,
#  'had': 3342,
#  'pay': 5147,
#  'returning': 5793,
#  'think': 6869,
#  'tantrum': 6732,
#  'finished': 2903,
#  'some': 6336,
#  'point': 5318,
#  'us': 7228,
#  'shopping': 6150,
#  'mark': 4390,
#  'distract': 2397,
#  'isaiah': 3796,
#  'sounds': 6380,
#  'great': 3286,
#  'sleep': 6259,
#  'night': 4803,
#  'why': 7511,
#  'official': 4929,
#  'england': 2636,
#  'poly': 5325,
#  'ringtone': 5823,
#  'colour': 1930,
#  'flag': 2926,
#  'yer': 7695,
#  'tonights': 6989,
#  'game': 3116,
#  'tone': 6981,
#  '84199': 688,
#  'optout': 5000,
#  'eng': 2633,
#  'stop': 6528,
#  'box39822': 1492,
#  'w111wx': 7348,
#  '50': 542,
#  'under': 7158,
#  'sea': 6001,
#  'there': 6854,
#  'lays': 4088,
#  'rock': 5839,
#  'envelope': 2661,
#  'paper': 5098,
#  'words': 7600,
#  'school': 5975,
#  'lab': 4033,
#  'stuff': 6572,
#  'give': 3193,
#  'go': 3209,
#  'until': 7196,
#  'jurong': 3919,
#  'crazy': 2101,
#  'bugis': 1585,
#  'world': 7607,
#  'la': 4029,
#  'buffet': 1583,
#  'cine': 1853,
#  'amore': 971,
#  'wat': 7405,
#  'gd': 3145,
#  'ice': 3634,
#  'cream': 2104,
#  'oso': 5024,
#  'wan': 7382,
#  'then': 6848,
#  'wait': 7363,
#  'aft': 869,
#  'lect': 4109,
#  'lar': 4063,
#  'dun': 2522,
#  'cheers': 1800,
#  'card': 1687,
#  'time': 6928,
#  'year': 7686,
#  'wiskey': 7556,
#  'brandy': 1512,
#  'rum': 5884,
#  'gin': 3186,
#  'beer': 1320,
#  'vodka': 7331,
#  'scotch': 5983,
#  'shampain': 6101,
#  'wine': 7538,
#  'kudi': 4021,
#  'yarasu': 7678,
#  'dhina': 2324,
#  'vaazhthukkal': 7252,
#  'granite': 3276,
#  'issues': 3805,
#  'strong': 6559,
#  'buy': 1614,
#  'explosive': 2763,
#  'members': 4466,
#  'over': 5052,
#  '300': 427,
#  'nasdaq': 4717,
#  'symbol': 6696,
#  'cdgt': 1731,
#  'per': 5172,
#  'oh': 4936,
#  'okie': 4945,
#  'lor': 4242,
#  'didnt': 2340,
#  'complete': 1961,
#  'gist': 3191,
#  'remind': 5720,
#  'shall': 6099,
#  'min': 4508,
#  'dint': 2369,
#  'wondarfull': 7587,
#  'song': 6354,
#  'stupid': 6577,
#  'possible': 5358,
#  'wnt': 7578,
#  'tlk': 6948,
#  '08718738001': 144,
#  '49557': 516,
#  '26': 371,
#  '11': 268,
#  'ryder': 5897,
#  'unsold': 7190,
#  'gibbs': 3179,
#  'tmr': 6953,
#  'timin': 6931,
#  'same': 5927,
#  'lesson': 4129,
#  'told': 6972,
#  'name': 4707,
#  'gautham': 3134,
#  'ah': 890,
#  'first': 2914,
#  'stock': 6519,
#  'guy': 3330,
#  'breathing': 1529,
#  'down': 2463,
#  'neck': 4746,
#  'bud': 1577,
#  'anyway': 1031,
#  'able': 770,
#  'track': 7026,
#  'usf': 7237,
#  'tonight': 6988,
#  'did': 2337,
#  'multimedia': 4662,
#  'them': 6845,
#  'mail': 4351,
#  'presnts': 5423,
#  'always': 955,
#  'bcz': 1297,
#  'mis': 4530,
#  'jeevithathile': 3858,
#  'irulinae': 3794,
#  'neekunna': 4756,
#  'prakasamanu': 5388,
#  'sneham': 6315,
#  'prakasam': 5387,
#  'ennal': 2644,
#  'prabha': 5379,
#  'mns': 4561,
#  'open': 4981,
#  'princess': 5444,
#  'moan': 4565,
#  'after': 870,
#  'noon': 4840,
#  'whens': 7493,
#  'radio': 5576,
#  'show': 6167,
#  'which': 7499,
#  'channel': 1763,
#  'didn': 2339,
#  'his': 3493,
#  'shadow': 6090,
#  'early': 2540,
#  'spring': 6450,
#  'yay': 7683,
#  'yo': 7706,
#  'carlos': 1699,
#  'few': 2859,
#  'friends': 3050,
#  'asking': 1125,
#  'working': 7605,
#  'weekend': 7450,
#  'designation': 2299,
#  'software': 6330,
#  'developer': 2316,
#  'may': 4427,
#  'hahaha': 3345,
#  'brain': 1507,
#  'dear': 2227,
#  'sapna': 5936,
#  'aunty': 1173,
#  'manege': 4376,
#  'hogidhe': 3512,
#  'chinnu': 1832,
#  'full': 3086,
#  'weak': 7426,
#  'swalpa': 6674,
#  'black': 1403,
#  'agidhane': 886,
#  'jolly': 3894,
#  'tickets': 6916,
#  '30': 426,
#  'speak': 6397,
#  'thats': 6835,
#  'ruin': 5880,
#  'thesis': 6858,
#  'cool': 2040,
#  'thank': 6827,
#  'selflessness': 6036,
#  'plenty': 5284,
#  'anyways': 1032,
#  'gym': 3334,
#  'whatever': 7484,
#  'smiles': 6295,
#  'ok': 4941,
#  'having': 3415,
#  'babe': 1210,
#  'persons': 5194,
#  'story': 6540,
#  'toa': 6959,
#  'payoh': 5155,
#  'place': 5256,
#  'walk': 7371,
#  'meh': 4458,
#  'important': 3678,
#  'information': 3724,
#  'orange': 5005,
#  'user': 7235,
#  '0789xxxxxxx': 38,
#  'lucky': 4288,
#  '2find': 388,
#  'log': 4213,
#  'onto': 4974,
#  'http': 3584,
#  'urawinner': 7215,
#  'fantastic': 2813,
#  'surprise': 6662,
#  'awaiting': 1190,
#  'hellogorgeous': 3452,
#  'hows': 3573,
#  'fone': 2970,
#  'charge': 1769,
#  'lst': 4281,
#  'nitw': 4817,
#  'texd': 6810,
#  'hopeu': 3545,
#  'ad': 825,
#  'wkend': 7567,
#  'sure': 6656,
#  'lookin': 4234,
#  '4ward': 539,
#  'jaz': 3851,
#  'mesages': 4480,
#  'hurts': 3612,
#  'congrats': 1996,
#  '3g': 463,
#  'videophones': 7299,
#  'yours': 7719,
#  '09061744553': 198,
#  'videochat': 7298,
#  'mates': 4409,
#  'play': 5270,
#  'java': 3848,
#  'games': 3117,
#  'dload': 2408,
#  'polyh': 5328,
#  'noline': 4835,
#  'rentl': 5735,
#  'bx420': 1623,
#  'ip4': 3781,
#  '5we': 574,
#  '150pm': 306,
#  'bishan': 1395,
#  'driving': 2493,
#  'okay': 4942,
#  'weather': 7433,
#  'cali': 1638,
#  'complexities': 1965,
#  'move': 4627,
#  'freely': 3035,
#  'taxes': 6744,
#  'outrageous': 5043,
#  'sad': 5905,
#  'part': 5115,
#  'missing': 4539,
#  'jordan': 3898,
#  'voted': 7338,
#  'nite': 4815,
#  'fighting': 2873,
#  'easy': 2551,
#  'either': 2590,
#  'lose': 4244,
#  'bt': 1571,
#  'fightng': 2874,
#  'some1': 6337,
#  'who': 7504,
#  'close': 1884,
#  'dificult': 2354,
#  'film': 2885,
#  '2day': 385,
#  '6pm': 616,
#  'booked': 1456,
#  'including': 3697,
#  'one': 4965,
#  'izzit': 3823,
#  'raining': 5583,
#  'norm': 4845,
#  'finish': 2901,
#  '15': 301,
#  'st': 6462,
#  'tests': 6808,
#  'sort': 6370,
#  'library': 4139,
#  'tomo': 6977,
#  'letter': 4133,
#  'access': 790,
#  'til': 6925,
#  'march': 4385,
#  'better': 1359,
#  'surfing': 6659,
#  'double': 2457,
#  'eviction': 2714,
#  'week': 7448,
#  'spiral': 6423,
#  'michael': 4494,
#  'riddance': 5811,
#  'services': 6067,
#  'inclusive': 3698,
#  'credits': 2110,
#  'goto': 3255,
#  'comuk': 1975,
#  'login': 4216,
#  '3qxj9': 472,
#  'unsubscribe': 7193,
#  'extra': 2770,
#  '08702840625': 76,
#  '220': 360,
#  'cm2': 1898,
#  '9ae': 748,
#  'calling': 1654,
#  'might': 4499,
#  'cancer': 1672,
#  'throat': 6899,
#  'talk': 6724,
#  'answering': 1012,
#  'everyones': 2709,
#  'calls': 1656,
#  'more': 4607,
#  'babysitting': 1217,
#  'monday': 4590,
#  'gobi': 3214,
#  'arts': 1108,
#  'college': 1929,
#  'many': 4380,
#  'antibiotic': 1019,
#  'used': 7233,
#  'chest': 1808,
#  'abdomen': 762,
#  'gynae': 3336,
#  'infections': 3719,
#  'even': 2698,
#  'bone': 1450,
#  'gettin': 3173,
#  'bit': 1396,
#  'arty': 1109,
#  'collages': 1922,
#  'mo': 4564,
#  'tryin': 7077,
#  'ne': 4738,
#  'roast': 5835,
#  'lovely': 4264,
#  'freemsg': 3036,
#  'fancy': 2810,
#  'flirt': 2940,
#  'date': 2206,
#  'join': 3886,
#  'uks': 7137,
#  'fastest': 2821,
#  'growing': 3302,
#  'dating': 2209,
#  'msgs': 4646,
#  'rcvd': 5617,
#  '25p': 370,
#  '83021': 673,
#  'almost': 941,
#  'sec': 6006,
#  'remember': 5715,
#  '80488': 660,
#  'credit': 2108,
#  'coming': 1943,
#  'wednesday': 7444,
#  'watching': 7410,
#  'ajith': 911,
#  'wont': 7592,
#  'friendship': 3052,
#  'umma': 7142,
#  'too': 6992,
#  'temales': 6784,
#  'ill': 3662,
#  'bhaji': 1368,
#  'cricketer': 2115,
#  'sachin': 5901,
#  'tough': 7018,
#  'accenture': 788,
#  'confirm': 1990,
#  'hi': 3478,
#  'gonna': 3231,
#  'blake': 1407,
#  'little': 4189,
#  'hmm': 3505,
#  'email': 2608,
#  'god': 3215,
#  'bless': 1413,
#  'pray': 5395,
#  'match': 4406,
#  'smart': 6285,
#  '200': 346,
#  'weekly': 7452,
#  'quiz': 5569,
#  '85222': 693,
#  'winnersclub': 7543,
#  'po': 5296,
#  'box': 1483,
#  '84': 685,
#  'm26': 4312,
#  '3uz': 475,
#  'gbp1': 3142,
#  'crucify': 2123,
#  'earlier': 2538,
#  'yeh': 7689,
#  'def': 2254,
#  'payed2day': 5150,
#  'havbeen': 3408,
#  'given': 3194,
#  'rise': 5827,
#  '4my': 529,
#  'havebeen': 3410,
#  'made': 4336,
#  'preschoolco': 5414,
#  'ordinator': 5011,
#  '2i': 395,
#  'feelingood': 2845,
#  'brothas': 1556,
#  'chasing': 1778,
#  'sitting': 6233,
#  'ard': 1075,
#  'nothing': 4857,
#  'leh': 4117,
#  'busy': 1609,
#  'remains': 5713,
#  'bro': 1549,
#  'amongst': 970,
#  'bros': 1554,
#  'skyped': 6253,
#  'wit': 7557,
#  'kz': 4023,
#  'sura': 6655,
#  'pleasure': 5282,
#  've': 7274,
#  'ultimatum': 7140,
#  'countin': 2070,
#  'aburo': 781,
#  'msg': 4640,
#  'yar': 7677,
#  'poor': 5338,
#  'thing': 6867,
#  'brand': 1511,
#  'fucks': 3081,
#  'sake': 5913,
#  'reality': 5635,
#  'fantasy': 2814,
#  '08707509020': 83,
#  '20p': 355,
#  'ntt': 4876,
#  'ltd': 4283,
#  '1327': 292,
#  'croydon': 2121,
#  'cr9': 2088,
#  '5wb': 573,
#  '0870': 65,
#  'national': 4725,
#  'rate': 5604,
#  '6times': 618,
#  'vijay': 7303,
#  'jaya': 3850,
#  'tv': 7099,
#  'romantic': 5850,
#  'paris': 5110,
#  'nights': 4806,
#  'flights': 2938,
#  '79': 638,
#  'next': 4791,
#  '08704439680ts': 79,
#  'apply': 1053,
#  'also': 948,
#  'piece': 5238,
#  'mmmmmm': 4558,
#  'ahmad': 895,
#  'begin': 1329,
#  'every': 2703,
#  'second': 6007,
#  'takes': 6719,
#  'closer': 1887,
#  'side': 6191,
#  'wot': 7617,
#  '1st': 334,
#  'textpod': 6820,
#  '40gb': 487,
#  'ipod': 3785,
#  '250': 368,
#  'cash': 1709,
#  'wk': 7566,
#  'vpod': 7342,
#  '81303': 666,
#  'ts': 7079,
#  'custcare': 2158,
#  '08712405020': 103,
#  'hiya': 3499,
#  'hlday': 3501,
#  'pics': 5233,
#  'looked': 4233,
#  'horrible': 3550,
#  'took': 6993,
#  ...}

# %%
X_train_np = X_train_cv.toarray()
X_train_np[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
np.where(X_train_np[0]!=0)
# Out:
# (array([4177, 4853, 6102, 6112, 6698, 7558], dtype=int64),)

# %%
X_train_np[0][7558]
# Out:
# 1

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X_train_cv, y_train)
# Out:
# MultinomialNB()

# %%
X_test_cv = v.transform(X_test)

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test_cv)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       956
#            1       0.97      0.91      0.94       159
#
#     accuracy                           0.98      1115
#    macro avg       0.98      0.95      0.96      1115
# weighted avg       0.98      0.98      0.98      1115

# %%
emails = [
    'Hey mohan, can we get together to watch footbal game tomorrow?',
    'Upto 20% discount on parking, exclusive offer just for you. Dont miss this reward!'
]

emails_count = v.transform(emails)
model.predict(emails_count)
# Out:
# array([0, 1], dtype=int64)

# %%
from sklearn.pipeline import Pipeline

clf = Pipeline([
    ('vectorizer', CountVectorizer()),
    ('nb', MultinomialNB())
])
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()), ('nb', MultinomialNB())])

# %%
y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       956
#            1       0.97      0.91      0.94       159
#
#     accuracy                           0.98      1115
#    macro avg       0.98      0.95      0.96      1115
# weighted avg       0.98      0.98      0.98      1115
